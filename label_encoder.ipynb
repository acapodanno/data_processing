# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/ProfAI/machine-learning-fondamenti/main/datasets/shirts_sold.csv"
df = pd.read_csv(url,index_col=0)
df.head()
# Out:
#   taglia  colore  prezzo venduta
# 0      S  bianco    4.99      NO
# 1      M  bianco   19.99      SI
# 2     XL  bianco   12.49      NO
# 3     XL  bianco   14.99      NO
# 4      S  bianco   14.99      SI

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["venduta"] = le.fit_transform(df["venduta"])
df.head()
# Out:
#   taglia  colore  prezzo  venduta
# 0      S  bianco    4.99        0
# 1      M  bianco   19.99        1
# 2     XL  bianco   12.49        0
# 3     XL  bianco   14.99        0
# 4      S  bianco   14.99        1

# %%
df["venduta"] = le.inverse_transform(df["venduta"])
df.head()
# Out:
#   taglia  colore  prezzo venduta
# 0      S  bianco    4.99      NO
# 1      M  bianco   19.99      SI
# 2     XL  bianco   12.49      NO
# 3     XL  bianco   14.99      NO
# 4      S  bianco   14.99      SI
